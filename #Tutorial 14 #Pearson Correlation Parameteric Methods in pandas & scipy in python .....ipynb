# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb
import scipy
from scipy.stats import pearsonr 

# %matplotlib inline
rcParams['figure.figsize']=10,8
sb.set_style('whitegrid')

# %%
address='C:/Users/Vivek Vishan Jetani/Desktop/vivek.csv'
ie=pd.read_csv(address)
ie.columns=['Gender','Category','SSC%','HSC%','classification','resource','place_of_study','attendance','GPA']
sb.pairplot(ie)

# %%
X=ie[['Gender','SSC%','HSC%','GPA']]
sb.pairplot(X)

# %%
corr=ie.corr()
corr
# Out:
#                 SSC%      HSC%  attendance       GPA
# SSC%        1.000000  0.201876    0.054757  0.196444
# HSC%        0.201876  1.000000   -0.055112 -0.141208
# attendance  0.054757 -0.055112    1.000000  0.268399
# GPA         0.196444 -0.141208    0.268399  1.000000

# %%
sb.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values)
