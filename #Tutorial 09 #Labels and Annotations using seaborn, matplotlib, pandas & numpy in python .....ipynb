# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %matplotlib inline
rcParams['figure.figsize']=5,4
sb.set_style('whitegrid')


x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]
plt.bar(x,y)
plt.xlabel('your x-axis label')
plt.ylabel('your y-axis label')
# Out:
# Text(0,0.5,'your y-axis label')

# %%
x=[1,2,3,4,5]
veh_type=['bycle','motorbike','car','van','stroller']
plt.pie(x, labels=veh_type)
plt.show()

# %%
address='G:/Python Tutorial/csv files/data/FYP_data1.csv'
ie=pd.read_csv(address)
ie.columns=['id','Age','Religion','Gender','MaterialStatus','Nationality','identification','Domicile','Category','hometown','school','SSC%','HSC%','classification','University','reachUniversity','Currently','Department','Year','GPA','attendance','resource','place','self-study','time','timesleep','Wheredoyoulive','foodfrom','expenses','askaboutstudy','satisfiedwithstudy','achievinggoal','supportsfromuniversity','uselibrary','satisfywithfacilities','satisfywithteachers','satisfied','satisfywithlaboratories','satisfywithclassrooms','satisfywithfood','member','political','helpfromseniors','accesstocomputer','extracurricularactivity','affect','job','affectuniversitywork']
GPA=ie.GPA
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
GPA.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(ie.id,rotation=60,fontsize='large')
ax.set_title('GPA of Higher Education Students')
ax.set_xlabel('Students Id')
ax.set_ylabel('GPA of Students')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-55cda54e3946> in <module>()
#       5 fig=plt.figure()
#       6 ax=fig.add_axes([.1,.1,1,1])
# ----> 7 GPA.plot()
#       8 ax.set_xticks(range(32))
#       9 ax.set_xticklabels(ie.id,rotation=60,fontsize='large')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
attendance=ie.attendance
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
attendance.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(ie.id,rotation=60,fontsize='large')
ax.set_title('Attendance of Higher Education Students')
ax.set_xlabel('Students Id')
ax.set_ylabel('Attendance of Students')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d31fe04c83db> in <module>()
#       2 fig=plt.figure()
#       3 ax=fig.add_axes([.1,.1,1,1])
# ----> 4 attendance.plot()
#       5 ax.set_xticks(range(32))
#       6 ax.set_xticklabels(ie.id,rotation=60,fontsize='large')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
plt.pie(x)
plt.legend(veh_type,loc='best')
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
GPA.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(ie.id,rotation=60,fontsize='large')
ax.set_title('GPA of Higher Education Students')
ax.set_xlabel('Students Id')
ax.set_ylabel('GPA of Students')
ax.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a6766a3d80ff> in <module>()
#       1 fig=plt.figure()
#       2 ax=fig.add_axes([.1,.1,1,1])
# ----> 3 GPA.plot()
#       4 ax.set_xticks(range(32))
#       5 ax.set_xticklabels(ie.id,rotation=60,fontsize='large')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
GPA.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna)
#     503         else:
# --> 504             result = getattr(values, meth)(axis)
#     505
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims)
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#
# TypeError: '>=' not supported between instances of 'str' and 'float'
#
# ...

# %%
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
GPA.plot()
ax.set_title('GPA of Higher Education Students')
ax.set_ylabel('GPA of Students')
ax.set_ylim([0,6])
ax.annotate('10', xy=(2,1), xytext=(1,4),arrowprops=dict(facecolor='black',shrink=0.05))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d8bbcdd5d316> in <module>()
#       1 fig=plt.figure()
#       2 ax=fig.add_axes([.1,.1,1,1])
# ----> 3 GPA.plot()
#       4 ax.set_title('GPA of Higher Education Students')
#       5 ax.set_ylabel('GPA of Students')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...
