# %%
# !pip install plotly==2.7.0
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb
from numpy.random import randn

# %matplotlib inline
rcParams['figure.figsize']=5,4
sb.set_style('whitegrid')
# Out:
# ...
#   Running setup.py bdist_wheel for plotly: started
#   Running setup.py bdist_wheel for plotly: finished with status 'done'
#   Stored in directory: C:\Users\Vivek Vishan Jetani\AppData\Local\pip\Cache\wheels\0c\3e\07\4848195c61f659184ca41d5a614845a018ab2d2f2a705b9998
# Successfully built plotly
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
address='G:/Python Tutorial/csv files/data/FYP_data1.csv'
df=pd.read_csv(address,index_col='GPA',parse_dates=True)
df.head
x=df['classification']
print(x)
plt.plot(x)
# Out:
# GPA
# 3.5 to 3.0            Government
# 3.5 to 3.0               Private
# 3.5 to 3.0               Private
# 4.0 to 3.6            Government
# 3.5 to 3.0       Semi-Government
# 3.5 to 3.0               Private
# Less than 2.5         Government
# Less than 2.5            Private
# 2.9 to 2.5            Government
# NaN                   Government
# 4.0 to 3.6            Government
# 4.0 to 3.6            Government
# 4.0 to 3.6            Government
# 3.5 to 3.0            Government
# 3.5 to 3.0            Government
# 4.0 to 3.6            Government
# 4.0 to 3.6            Government
# 3.5 to 3.0               Private
# 2.9 to 2.5       Semi-Government
# 2.9 to 2.5            Government
# 2.9 to 2.5            Government
# 3.5 to 3.0            Government
# 3.5 to 3.0       Semi-Government
# 3.5 to 3.0               Private
# 3.5 to 3.0       Semi-Government
# Less than 2.5         Government
# NaN                   Government
# 4.0 to 3.6            Government
# ...

# %%
df2=df.sample(n=32,random_state=25,axis=0)
plt.xlabel('GPA')
plt.ylabel('Classification')
plt.title('GPA vs Classification')
x=df2['classification']
print(x)
plt.plot(x)
# Out:
# GPA
# 3.5 to 3.0            Government
# NaN                   Government
# 3.5 to 3.0            Government
# Less than 2.5         Government
# 3.5 to 3.0               Private
# 4.0 to 3.6            Government
# 2.9 to 2.5               Private
# Less than 2.5         Government
# 3.5 to 3.0            Government
# 2.9 to 2.5            Government
# 4.0 to 3.6       Semi-Government
# 4.0 to 3.6            Government
# 3.5 to 3.0            Government
# 2.9 to 2.5            Government
# 2.9 to 2.5            Government
# 3.5 to 3.0            Government
# 3.5 to 3.0            Government
# 3.5 to 3.0            Government
# 4.0 to 3.6            Government
# 4.0 to 3.6            Government
# 3.5 to 3.0               Private
# 3.5 to 3.0               Private
# Less than 2.5         Government
# 4.0 to 3.6            Government
# 2.9 to 2.5            Government
# 4.0 to 3.6            Government
# 3.5 to 3.0            Government
# NaN                   Government
# ...

# %%
df2=df.sample(n=32,random_state=25,axis=0)
plt.xlabel('GPA')
plt.ylabel('Classification')
plt.title('GPA vs Classification')
x=df2['classification']
print(x)
plt.plot(x)
# Out:
# GPA
# 3.5 to 3.0            Government
# NaN                   Government
# 3.5 to 3.0            Government
# Less than 2.5         Government
# 3.5 to 3.0               Private
# 4.0 to 3.6            Government
# 2.9 to 2.5               Private
# Less than 2.5         Government
# 3.5 to 3.0            Government
# 2.9 to 2.5            Government
# 4.0 to 3.6       Semi-Government
# 4.0 to 3.6            Government
# 3.5 to 3.0            Government
# 2.9 to 2.5            Government
# 2.9 to 2.5            Government
# 3.5 to 3.0            Government
# 3.5 to 3.0            Government
# 3.5 to 3.0            Government
# 4.0 to 3.6            Government
# 4.0 to 3.6            Government
# 3.5 to 3.0               Private
# 3.5 to 3.0               Private
# Less than 2.5         Government
# 4.0 to 3.6            Government
# 2.9 to 2.5            Government
# 4.0 to 3.6            Government
# 3.5 to 3.0            Government
# NaN                   Government
# ...

# %%
df2=df.sample(n=32,random_state=25,axis=0)
plt.xlabel('GPA')
plt.ylabel('Classification')
plt.title('GPA vs Classification')
x=df2['classification']
x.plot(kind='hist')
plt.hist(x)
plt.plot()
sb.distplot(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-334c9007e3cf> in <module>()
#       4 plt.title('GPA vs Classification')
#       5 x=df2['classification']
# ----> 6 x.plot(kind='hist')
#       7 plt.hist(x)
#       8 plt.plot()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...
