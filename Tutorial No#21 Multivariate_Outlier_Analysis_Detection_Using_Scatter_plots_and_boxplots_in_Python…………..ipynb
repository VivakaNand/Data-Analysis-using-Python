# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb
# %matplotlib inline
rcParams['figure.figsize']=5,4
sb.set_style('whitegrid')

# %%
ie=pd.read_csv(filepath_or_buffer='G:/Python Tutorial/csv files/data/FYP_data1.csv',header=None,sep=',')
ie.columns=['id','Age','Religion','Gender','MaterialStatus','Nationality','identification','Domicile','Category','hometown','school','SSC%','HSC%','classification','University','reachUniversity','Currently','Department','Year','GPA','attendance','resource','place','self-study','time','timesleep','Wheredoyoulive','foodfrom','expenses','askaboutstudy','satisfiedwithstudy','achievinggoal','supportsfromuniversity','uselibrary','satisfywithfacilities','satisfywithteachers','satisfied','satisfywithlaboratories','satisfywithclassrooms','satisfywithfood','member','political','helpfromseniors','accesstocomputer','extracurricularactivity','affect','job','affectuniversitywork']
X=ie.iloc[:,0:4].values
Y=ie.iloc[:,4].values
ie[:5]
# Out:
#    id       Age  Religion  Gender MaterialStatus  Nationality  identification  \
# 0  id       Age  Religion  Gender  MeritalStatus  Nationality  identification
# 1   1  21 to 25     Hindu    Male      Unmarried     Pakistan          Sindhi
# 2   2  21 to 25     Islam    Male      Unmarried     Pakistan   Urdu Speaking
# 3   3  21 to 25     Islam    Male      Unmarried     Pakistan   Urdu Speaking
# 4   4  21 to 25     Islam    Male      Unmarried     Pakistan       Pakistani
#
#    Domicile  Category  hometown          ...           satisfywithclassrooms  \
# 0  Domicile  Category  hometown          ...           satisfywithclassrooms
# 1   Umarkot     Rural   Umarkot          ...                              No
# 2   Karachi     Urban   Karachi          ...                             Yes
# 3   Karachi     Urban   Korangi          ...                             Yes
# 4   Karachi     Rural   Karachi          ...                             Yes
#
#    satisfywithfood  member  political  helpfromseniors  accesstocomputer  \
# 0  satisfywithfood  member  political  helpfromseniors  accesstocomputer
# 1               No      No         No              Yes               Yes
# 2              Yes     Yes         No              Yes               Yes
# 3              Yes     Yes         No               No               Yes
# 4               No      No         No               No               Yes
#
#    extracurricularactivity  affect  job  affectuniversitywork
# 0  extracurricularactivity  affect  job  affectuniversitywork
# 1                       No     Yes   No                   Yes
# 2                      Yes     Yes   No                   Yes
# 3                       No     Yes   No                    No
# 4                      Yes      No   No                    No
#
# [5 rows x 48 columns]

# %%
sb.boxplot(X='GPA',Y='classification',data=ie, palette='hls')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e4abbd6a3379> in <module>()
# ----> 1 sb.boxplot(X='GPA',Y='classification',data=ie, palette='hls')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2209     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2210                           orient, color, palette, saturation,
# -> 2211                           width, dodge, fliersize, linewidth)
#    2212
#    2213     if ax is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     440
#     441         self.establish_variables(x, y, hue, data, orient, order, hue_order)
# --> 442         self.establish_colors(color, palette, saturation)
#     443
#     444         self.dodge = dodge
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in establish_colors(self, color, palette, saturation)
#     309         # Determine the gray color to use for the lines framing the plot
#     310         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 311         l = min(light_vals) * .6
#     312         gray = mpl.colors.rgb2hex((l, l, l))
#     313
#
# ValueError: min() arg is an empty sequence

# %%
sb.pairplot(ie, hue='GPA', palette='hls')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-8ca3b5537573> in <module>()
# ----> 1 sb.pairplot(ie, hue='GPA', palette='hls')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2039                     hue_order=hue_order, palette=palette,
#    2040                     diag_sharey=diag_sharey,
# -> 2041                     size=size, aspect=aspect, dropna=dropna, **grid_kws)
#    2042
#    2043     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, size, aspect, despine, dropna)
#    1243
#    1244         # Label the axes
# -> 1245         self._add_axis_labels()
#    1246
#    1247         # Sort out the hue variable
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py in _add_axis_labels(self)
#    1497     def _add_axis_labels(self):
#    1498         """Add labels to the left and bottom Axes."""
# -> 1499         for ax, label in zip(self.axes[-1, :], self.x_vars):
#    1500             ax.set_xlabel(label)
#    1501         for ax, label in zip(self.axes[:, 0], self.y_vars):
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
